# %% [markdown]
# # SUPABASE

# %% [markdown]
# ## 1. INSTALL LIBRARIES

# %%
# !pip install supabase python-dotenv dotenv
# Out:
# Requirement already satisfied: supabase in c:\users\alexandre pedro\desktop\base_coding\classes\data_analytics\.venv\lib\site-packages (2.23.2)
# Requirement already satisfied: python-dotenv in c:\users\alexandre pedro\desktop\base_coding\classes\data_analytics\.venv\lib\site-packages (1.1.1)
# Requirement already satisfied: dotenv in c:\users\alexandre pedro\desktop\base_coding\classes\data_analytics\.venv\lib\site-packages (0.9.9)
# Requirement already satisfied: realtime==2.23.2 in c:\users\alexandre pedro\desktop\base_coding\classes\data_analytics\.venv\lib\site-packages (from supabase) (2.23.2)
# Requirement already satisfied: supabase-functions==2.23.2 in c:\users\alexandre pedro\desktop\base_coding\classes\data_analytics\.venv\lib\site-packages (from supabase) (2.23.2)
# Requirement already satisfied: storage3==2.23.2 in c:\users\alexandre pedro\desktop\base_coding\classes\data_analytics\.venv\lib\site-packages (from supabase) (2.23.2)
# Requirement already satisfied: supabase-auth==2.23.2 in c:\users\alexandre pedro\desktop\base_coding\classes\data_analytics\.venv\lib\site-packages (from supabase) (2.23.2)
# Requirement already satisfied: postgrest==2.23.2 in c:\users\alexandre pedro\desktop\base_coding\classes\data_analytics\.venv\lib\site-packages (from supabase) (2.23.2)
# Requirement already satisfied: httpx<0.29,>=0.26 in c:\users\alexandre pedro\desktop\base_coding\classes\data_analytics\.venv\lib\site-packages (from supabase) (0.28.1)
# Requirement already satisfied: deprecation>=2.1.0 in c:\users\alexandre pedro\desktop\base_coding\classes\data_analytics\.venv\lib\site-packages (from postgrest==2.23.2->supabase) (2.1.0)
# Requirement already satisfied: pydantic<3.0,>=1.9 in c:\users\alexandre pedro\desktop\base_coding\classes\data_analytics\.venv\lib\site-packages (from postgrest==2.23.2->supabase) (2.12.3)
# Requirement already satisfied: yarl>=1.20.1 in c:\users\alexandre pedro\desktop\base_coding\classes\data_analytics\.venv\lib\site-packages (from postgrest==2.23.2->supabase) (1.22.0)
# Requirement already satisfied: typing-extensions>=4.14.0 in c:\users\alexandre pedro\desktop\base_coding\classes\data_analytics\.venv\lib\site-packages (from realtime==2.23.2->supabase) (4.15.0)
# Requirement already satisfied: websockets<16,>=11 in c:\users\alexandre pedro\appdata\local\programs\python\python312\lib\site-packages (from realtime==2.23.2->supabase) (15.0.1)
# Requirement already satisfied: pyjwt>=2.10.1 in c:\users\alexandre pedro\desktop\base_coding\classes\data_analytics\.venv\lib\site-packages (from pyjwt[crypto]>=2.10.1->supabase-auth==2.23.2->supabase) (2.10.1)
# Requirement already satisfied: strenum>=0.4.15 in c:\users\alexandre pedro\desktop\base_coding\classes\data_analytics\.venv\lib\site-packages (from supabase-functions==2.23.2->supabase) (0.4.15)
# Requirement already satisfied: anyio in c:\users\alexandre pedro\desktop\base_coding\classes\data_analytics\.venv\lib\site-packages (from httpx<0.29,>=0.26->supabase) (4.11.0)
# Requirement already satisfied: certifi in c:\users\alexandre pedro\desktop\base_coding\classes\data_analytics\.venv\lib\site-packages (from httpx<0.29,>=0.26->supabase) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in c:\users\alexandre pedro\desktop\base_coding\classes\data_analytics\.venv\lib\site-packages (from httpx<0.29,>=0.26->supabase) (1.0.9)
# Requirement already satisfied: idna in c:\users\alexandre pedro\desktop\base_coding\classes\data_analytics\.venv\lib\site-packages (from httpx<0.29,>=0.26->supabase) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\users\alexandre pedro\desktop\base_coding\classes\data_analytics\.venv\lib\site-packages (from httpcore==1.*->httpx<0.29,>=0.26->supabase) (0.16.0)
# Requirement already satisfied: h2<5,>=3 in c:\users\alexandre pedro\desktop\base_coding\classes\data_analytics\.venv\lib\site-packages (from httpx[http2]<0.29,>=0.26->postgrest==2.23.2->supabase) (4.3.0)
# Requirement already satisfied: hyperframe<7,>=6.1 in c:\users\alexandre pedro\desktop\base_coding\classes\data_analytics\.venv\lib\site-packages (from h2<5,>=3->httpx[http2]<0.29,>=0.26->postgrest==2.23.2->supabase) (6.1.0)
# Requirement already satisfied: hpack<5,>=4.1 in c:\users\alexandre pedro\desktop\base_coding\classes\data_analytics\.venv\lib\site-packages (from h2<5,>=3->httpx[http2]<0.29,>=0.26->postgrest==2.23.2->supabase) (4.1.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\alexandre pedro\desktop\base_coding\classes\data_analytics\.venv\lib\site-packages (from pydantic<3.0,>=1.9->postgrest==2.23.2->supabase) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in c:\users\alexandre pedro\desktop\base_coding\classes\data_analytics\.venv\lib\site-packages (from pydantic<3.0,>=1.9->postgrest==2.23.2->supabase) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\alexandre pedro\desktop\base_coding\classes\data_analytics\.venv\lib\site-packages (from pydantic<3.0,>=1.9->postgrest==2.23.2->supabase) (0.4.2)
# Requirement already satisfied: packaging in c:\users\alexandre pedro\desktop\base_coding\classes\data_analytics\.venv\lib\site-packages (from deprecation>=2.1.0->postgrest==2.23.2->supabase) (25.0)
# Requirement already satisfied: cryptography>=3.4.0 in c:\users\alexandre pedro\desktop\base_coding\classes\data_analytics\.venv\lib\site-packages (from pyjwt[crypto]>=2.10.1->supabase-auth==2.23.2->supabase) (46.0.3)
# Requirement already satisfied: cffi>=2.0.0 in c:\users\alexandre pedro\desktop\base_coding\classes\data_analytics\.venv\lib\site-packages (from cryptography>=3.4.0->pyjwt[crypto]>=2.10.1->supabase-auth==2.23.2->supabase) (2.0.0)
# Requirement already satisfied: pycparser in c:\users\alexandre pedro\desktop\base_coding\classes\data_analytics\.venv\lib\site-packages (from cffi>=2.0.0->cryptography>=3.4.0->pyjwt[crypto]>=2.10.1->supabase-auth==2.23.2->supabase) (2.23)
# Requirement already satisfied: multidict>=4.0 in c:\users\alexandre pedro\desktop\base_coding\classes\data_analytics\.venv\lib\site-packages (from yarl>=1.20.1->postgrest==2.23.2->supabase) (6.7.0)
# Requirement already satisfied: propcache>=0.2.1 in c:\users\alexandre pedro\desktop\base_coding\classes\data_analytics\.venv\lib\site-packages (from yarl>=1.20.1->postgrest==2.23.2->supabase) (0.4.1)
# Requirement already satisfied: sniffio>=1.1 in c:\users\alexandre pedro\desktop\base_coding\classes\data_analytics\.venv\lib\site-packages (from anyio->httpx<0.29,>=0.26->supabase) (1.3.1)
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ## 2. CONNECTION WITH DATABASE

# %%
import os
import pandas as pd
from dotenv import load_dotenv
from supabase import create_client

load_dotenv()

SUPABASE_URL = os.getenv(key='SUPABASE_URL')
SUPABASE_KEY = os.getenv(key='SUPABASE_KEY')

supabase = create_client(supabase_url=SUPABASE_URL, supabase_key=SUPABASE_KEY)

# %% [markdown]
# ## 3. READ DATA

# %%
STORES_TABLE = "stores"
FIELDS = "*"

stores = supabase.table(table_name=STORES_TABLE).select(FIELDS).execute()
stores_data = stores.data
stores_data
# Out:
# [{'unit': 'SP', 'revenue': 12000.0, 'month': 1},
#  {'unit': 'SP', 'revenue': 15000.0, 'month': 2},
#  {'unit': 'SP', 'revenue': 13500.0, 'month': 3},
#  {'unit': 'RJ', 'revenue': 22000.0, 'month': 1},
#  {'unit': 'RJ', 'revenue': 25000.0, 'month': 2},
#  {'unit': 'RJ', 'revenue': 3500.0, 'month': 3},
#  {'unit': 'MG', 'revenue': 1250.0, 'month': 1},
#  {'unit': 'MG', 'revenue': 3250.0, 'month': 2},
#  {'unit': 'MG', 'revenue': 4250.0, 'month': 3},
#  {'unit': 'SP', 'revenue': 14200.0, 'month': 4},
#  {'unit': 'SP', 'revenue': 18900.0, 'month': 5},
#  {'unit': 'SP', 'revenue': 2000.0, 'month': 6},
#  {'unit': 'RJ', 'revenue': 4200.0, 'month': 4},
#  {'unit': 'RJ', 'revenue': 18900.0, 'month': 5},
#  {'unit': 'RJ', 'revenue': 2500.0, 'month': 6},
#  {'unit': 'MG', 'revenue': 7250.0, 'month': 4},
#  {'unit': 'MG', 'revenue': 6750.0, 'month': 5}]

# %%
df_stores = pd.DataFrame(data=stores_data)
df_stores
# Out:
#    unit  revenue  month
# 0    SP  12000.0      1
# 1    SP  15000.0      2
# 2    SP  13500.0      3
# 3    RJ  22000.0      1
# 4    RJ  25000.0      2
# 5    RJ   3500.0      3
# 6    MG   1250.0      1
# 7    MG   3250.0      2
# 8    MG   4250.0      3
# 9    SP  14200.0      4
# 10   SP  18900.0      5
# 11   SP   2000.0      6
# 12   RJ   4200.0      4
# 13   RJ  18900.0      5
# 14   RJ   2500.0      6
# 15   MG   7250.0      4
# 16   MG   6750.0      5

# %% [markdown]
# ## 4. MANIPULATING DATA ON SUPABASE VIA PYTHON

# %% [markdown]
# ### 4.1. GET FIELD(S) FROM TABLE

# %%
FIELD = 'unit'
FIELD_VALUE = 'SP'

stores = supabase.table(table_name=STORES_TABLE).select(FIELDS).eq(FIELD, FIELD_VALUE).execute()
stores_data = stores.data
stores_data
# Out:
# [{'unit': 'SP', 'revenue': 12000.0, 'month': 1},
#  {'unit': 'SP', 'revenue': 15000.0, 'month': 2},
#  {'unit': 'SP', 'revenue': 13500.0, 'month': 3},
#  {'unit': 'SP', 'revenue': 14200.0, 'month': 4},
#  {'unit': 'SP', 'revenue': 18900.0, 'month': 5},
#  {'unit': 'SP', 'revenue': 2000.0, 'month': 6}]

# %% [markdown]
# ### 4.2. INSERT INTO TABLE

# %%
insert_data = {
    'unit': 'PA',
    'revenue': 45000,
    'month': 1
}

stores = supabase.table(table_name=STORES_TABLE).insert(json=insert_data, upsert=True).execute()
stores_data = stores.data
stores_data
# Out:
# [{'unit': 'PA', 'revenue': 45000.0, 'month': 1}]

# %% [markdown]
# ### 4.3. UPDATE DATA

# %% [markdown]
# #### 4.3.1. USING EQUAL (EQ)

# %%
update_obj1 = { 'revenue': 66000 }
eq_obj_key1 = 'unit'
eq_obj_value1 = 'PA'
eq_obj_key2 = 'month'
eq_obj_value2 = 1

stores = supabase.table(table_name=STORES_TABLE).update(json=update_obj1).eq(eq_obj_key1, eq_obj_value1).eq(eq_obj_key2, eq_obj_value2).execute()
stores_data = stores.data
stores_data
# Out:
# [{'unit': 'PA', 'revenue': 66000.0, 'month': 1}]

# %% [markdown]
# #### 4.3.2. USING MATCH

# %%
update_obj2 = { 'revenue': 76000 }
match_obj = {
    'unit': 'PA',
    'month': 1
}

stores = supabase.table(table_name=STORES_TABLE).update(json=update_obj2).match(query=match_obj).execute()
stores_data = stores.data
stores_data
# Out:
# [{'unit': 'PA', 'revenue': 76000.0, 'month': 1}]

# %% [markdown]
# ### 4.4. DELETE DATA

# %%
DELETE_MATCH_OBJ = {
    'unit': 'PA',
    # 'month': 2
    'month': 1
}
SEARCH_FIELD_KEY = 'unit'
SEARCH_FIELD_VALUE = 'PA'

deleted_store = supabase.table(table_name=STORES_TABLE).delete().match(query=DELETE_MATCH_OBJ).execute()
deleted_store_data = deleted_store.data
print(deleted_store_data)

remaining_stores = supabase.table(table_name=STORES_TABLE).select(FIELDS).eq(SEARCH_FIELD_KEY, SEARCH_FIELD_VALUE).execute()
remaining_stores_data = remaining_stores.data
remaining_stores
# Out:
# []
# APIResponse(data=[], count=None)
